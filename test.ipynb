# %%
from openai import OpenAI

client = OpenAI() 
#this is how I instantiated client, 
# if it had been openai_client the we would be same as the video

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input="Write a short bedtime story about a unicorn"
)

# %%
print(response.output_text)
# Out:
# ### Luna the Starry Unicorn
#
# Once upon a time, in a land where dreams danced like fireflies, there lived a little unicorn named Luna. With a shimmering silver coat and a sparkling horn, she roamed the enchanting Glimmering Grove, where the trees whispered secrets and the rivers sang lullabies.
#
# Every night, as the sun dipped below the horizon, Luna would gaze up at the stars twinkling in the velvety sky. “I wish I could touch a star,” she sighed. It was her greatest dream!
#
# One evening, as Luna wandered through the grove, she met a wise old owl named Oliver. His feathers were a deep midnight blue, and his eyes sparkled like the stars above.
#
# “Why are you looking so wistful, dear Luna?” Oliver hooted gently.
#
# “Oh, Oliver, I want to touch a star!” she replied, her voice filled with longing.
#
# Oliver smiled kindly. “To touch a star, you must first believe in the magic of your dreams.” He pointed his wing toward the tallest hill in the grove. “Climb to the top, and shout your wish into the moonlit sky!”
#
# Excitedly, Luna raced up the hill, her heart pounding with anticipation. When she reached the top, she took a deep breath and called out, “I wish to touch a star!”
#
# Suddenly, the night sky shimmered, and one particularly bright star began to twinkle more than the rest. It descended slowly, growing larger and brighter until it floated just above her. Luna gasped in awe.
#
# “Hello, Luna! I am Stella, the Star of Dreams!” said the glowing star in a gentle, melodic voice. “You believed in your wish, and here I am!”
#
# Overjoyed, Luna reached up, her heart thumping with happiness. As her horn touched the star, it burst into a shower of sparkles, enveloping Luna in a warm, magical glow. She felt lighter, like she was dancing among the stars.
#
# “Whenever you look up at the night sky, remember that your dreams are always within reach,” Stella whispered before soaring back into the heavens.
#
# From that night on, Luna knew she could always touch the stars in her heart. And each evening, as she lay beneath the twinkling sky, she believed in the magic of her dreams, knowing they were just a wish away.
#
# And so, under the shimmering blanket of the night, Luna drifted into sleep, dreaming of adventures among the stars.
#
# **The End.**

# %%
messages = [
    {"role":"user", "content":"tell me a joke about Alexey"}
]

response = client.responses.create(
    model="gpt-4o-mini",
    input=messages
)

# %%
print(response.output_text)
# Out:
# Why did Alexey bring a ladder to the bar?
#
# Because he heard the drinks were on the house!

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "resp_03017c332bf9a0fc00698905f13d3c8199825002fd9e1251d0",
#   "created_at": 1770587633.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": null,
#   "metadata": {},
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "response",
#   "output": [
#     {
#       "id": "msg_03017c332bf9a0fc00698905f236848199afecb820be77ae74",
#       "content": [
#         {
#           "annotations": [],
#           "text": "Why did Alexey bring a ladder to the bar?\n\nBecause he heard the drinks were on the house!",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "parallel_tool_calls": true,
#   "temperature": 1.0,
#   "tool_choice": "auto",
#   "tools": [],
#   "top_p": 1.0,
#   "background": false,
#   "completed_at": 1770587634.0,
#   "conversation": null,
#   "max_output_tokens": null,
#   "max_tool_calls": null,
#   "previous_response_id": null,
#   "prompt": null,
#   "prompt_cache_key": null,
#   "prompt_cache_retention": null,
#   "reasoning": {
#     "effort": null,
#     "generate_summary": null,
#     "summary": null
#   },
#   "safety_identifier": null,
#   "service_tier": "default",
#   "status": "completed",
#   "text": {
#     "format": {
#       "type": "text"
#     },
#     "verbosity": "medium"
#   },
#   "top_logprobs": 0,
#   "truncation": "disabled",
#   "usage": {
#     "input_tokens": 14,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens": 22,
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     },
#     "total_tokens": 36
#   },
#   "user": null,
#   "billing": {
#     "payer": "openai"
#   },
#   "frequency_penalty": 0.0,
#   "presence_penalty": 0.0,
#   "store": true
# }

# %%
response.output[0].content[0].text
# Out:
# 'Why did Alexey bring a ladder to the bar?\n\nBecause he heard the drinks were on the house!'
